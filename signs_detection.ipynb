# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
cv2.__version__
# Out:
# '4.5.2'

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %%
#2. Capture Landmarks & Export to CSV
import csv
import os
import numpy as np
from matplotlib import pyplot as plt
import uuid
import time
import schedule

# %% [markdown]
# # This Function tell me wich hand is intialized

# %%
def isInitialized(hand):
    try:
        if hand.IsInitialized() == True:
            return True
    except: return False

# %% [markdown]
# # this code to initialized coordinates

# %%
    sec=(time.localtime().tm_sec+45)%60
    sec2 = time.localtime().tm_sec 
    
    print('called')
    time.sleep(5)
    print('called after break 5s')
    cap = cv2.VideoCapture(0)
    # Initiate holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

        while cap.isOpened() and sec2%60!=sec :
            
            sec2 = time.localtime().tm_sec
            ret, frame = cap.read()

            # Recolor Feed
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        

            # Make Detections
            results = holistic.process(image)
            # print(results.face_landmarks)

            # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks

            # Recolor image back to BGR for rendering
            image.flags.writeable = True   
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # 1. Draw face landmarks
            mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                     mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                     )

            # 2. Right hand
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                     )

            # 3. Left Hand
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                     )
            

            # 4. Pose Detections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                     mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                     mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                     )

            cv2.imshow('Raw Webcam Feed', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# called
# called after break 5s

# %%
results.pose_landmarks.landmark
# Out:
# [x: 0.522842526435852
# y: 0.6082943081855774
# z: -0.8092347979545593
# visibility: 0.9999397993087769
# , x: 0.5437563061714172
# y: 0.5544590353965759
# z: -0.7344735860824585
# visibility: 0.9998825788497925
# , x: 0.5582747459411621
# y: 0.5572533011436462
# z: -0.7351842522621155
# visibility: 0.9998817443847656
# , x: 0.5730320811271667
# y: 0.559765100479126
# z: -0.7354761958122253
# visibility: 0.9998908042907715
# , x: 0.4983208179473877
# y: 0.5481563210487366
# z: -0.74904865026474
# visibility: 0.9998030066490173
# , x: 0.4810113310813904
# y: 0.54737788438797
# z: -0.7485219240188599
# visibility: 0.9997671842575073
# , x: 0.4638521671295166
# y: 0.5469279885292053
# z: -0.748353898525238
# visibility: 0.9997768998146057
# , x: 0.5918378829956055
# y: 0.5816689729690552
# z: -0.2791483998298645
# visibility: 0.9999299049377441
# , x: 0.4265747666358948
# y: 0.5590824484825134
# z: -0.3339661955833435
# visibility: 0.9998539686203003
# , x: 0.5442699193954468
# y: 0.6759873032569885
# z: -0.6419460773468018
# visibility: 0.999968409538269
# , x: 0.48739442229270935
# y: 0.6696001887321472
# z: -0.6586869955062866
# visibility: 0.9999582171440125
# , x: 0.7017507553100586
# y: 0.881805956363678
# z: -0.13151097297668457
# visibility: 0.9997525811195374
# , x: 0.256747305393219
# y: 0.836549699306488
# z: -0.27537375688552856
# visibility: 0.9994139075279236
# , x: 1.027199625968933
# y: 0.9678369760513306
# z: -0.832147479057312
# visibility: 0.9881943464279175
# , x: -0.027658134698867798
# y: 0.8555772304534912
# z: -0.9370013475418091
# visibility: 0.9846550226211548
# , x: 0.8575640916824341
# y: 0.7032883167266846
# z: -1.5552493333816528
# visibility: 0.9967267513275146
# , x: 0.18317505717277527
# y: 0.5698708891868591
# z: -1.5662944316864014
# visibility: 0.9722068309783936
# , x: 0.835680365562439
# y: 0.566879391670227
# z: -1.7013623714447021
# visibility: 0.984772801399231
# , x: 0.22842678427696228
# y: 0.4781365990638733
# z: -1.7191931009292603
# visibility: 0.9133138060569763
# , x: 0.7847760319709778
# y: 0.569551408290863
# z: -1.5846097469329834
# visibility: 0.9828267693519592
# , x: 0.2727900743484497
# y: 0.4817088544368744
# z: -1.5756399631500244
# visibility: 0.914065957069397
# , x: 0.781653106212616
# y: 0.6244595050811768
# z: -1.540229082107544
# visibility: 0.9834384918212891
# , x: 0.26943522691726685
# y: 0.5198288559913635
# z: -1.5374847650527954
# visibility: 0.9150899648666382
# , x: 0.6270928978919983
# y: 1.6771596670150757
# z: -0.002017526188865304
# visibility: 0.008771684020757675
# , x: 0.31292247772216797
# y: 1.6747992038726807
# z: 0.010364427231252193
# visibility: 0.008229590021073818
# , x: 0.6288667321205139
# y: 2.3399007320404053
# z: -0.3804861307144165
# visibility: 0.0004082053492311388
# , x: 0.34100958704948425
# y: 2.350698947906494
# z: -0.16813570261001587
# visibility: 0.00013615998614113778
# , x: 0.6125466227531433
# y: 2.9397895336151123
# z: 0.16543373465538025
# visibility: 7.186097263911506e-06
# , x: 0.3375203609466553
# y: 2.9513354301452637
# z: 0.4226617217063904
# visibility: 5.793553555122344e-06
# , x: 0.6167601346969604
# y: 3.0228729248046875
# z: 0.19958777725696564
# visibility: 1.2190762390673626e-05
# , x: 0.32394587993621826
# y: 3.0276362895965576
# z: 0.45992550253868103
# visibility: 8.264844836958218e-06
# , x: 0.584742546081543
# y: 3.1335484981536865
# z: -0.30387985706329346
# visibility: 2.623008913360536e-05
# , x: 0.400750070810318
# y: 3.1508841514587402
# z: -0.029918521642684937
# visibility: 2.5418519726372324e-05
# ]

# %%
pose = results.right_hand_landmarks.landmark
pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
pose_row
# Out:
# [0.16967542469501495,
#  0.5811815857887268,
#  -4.9005535402102396e-05,
#  0.0,
#  0.22495879232883453,
#  0.5935651659965515,
#  -0.018255816772580147,
#  0.0,
#  0.282906711101532,
#  0.5756496787071228,
#  -0.023988081142306328,
#  0.0,
#  0.32397180795669556,
#  0.5531638860702515,
#  -0.03657092526555061,
#  0.0,
#  0.35700172185897827,
#  0.5423387885093689,
#  -0.05201874300837517,
#  0.0,
#  0.2868407964706421,
#  0.45432090759277344,
#  0.026728611439466476,
#  0.0,
#  0.3165546655654907,
#  0.39924949407577515,
#  0.023460332304239273,
#  0.0,
#  0.33345943689346313,
#  0.36564260721206665,
#  0.017653681337833405,
#  0.0,
#  0.3473607897758484,
#  0.3355969786643982,
#  0.01183713786303997,
#  0.0,
#  0.26389217376708984,
#  0.42919865250587463,
#  0.02233707346022129,
#  0.0,
#  0.2937459349632263,
#  0.36703377962112427,
#  0.027296749874949455,
#  0.0,
#  0.31086644530296326,
#  0.32913967967033386,
#  0.024078037589788437,
#  0.0,
#  0.32410097122192383,
#  0.29832059144973755,
#  0.0212913416326046,
#  0.0,
#  0.23722608387470245,
#  0.4175489842891693,
#  0.010619662702083588,
#  0.0,
#  0.26153337955474854,
#  0.3575896918773651,
#  0.010939724743366241,
#  0.0,
#  0.2780098021030426,
#  0.3227766454219818,
#  0.006698753219097853,
#  0.0,
#  0.29230839014053345,
#  0.296642005443573,
#  0.0048460629768669605,
#  0.0,
#  0.20560908317565918,
#  0.41794198751449585,
#  -0.007403127383440733,
#  0.0,
#  0.21874040365219116,
#  0.3667742908000946,
#  -0.011502652429044247,
#  0.0,
#  0.2292938381433487,
#  0.3379215598106384,
#  -0.015287905000150204,
#  0.0,
#  0.2396651804447174,
#  0.31488123536109924,
#  -0.017460064962506294,
#  0.0]

# %%
results.left_hand_landmarks.landmark
# Out:
# [x: 0.8651241064071655
# y: 0.6819627285003662
# z: -3.4100190532626584e-05
# , x: 0.8119996786117554
# y: 0.6874812245368958
# z: -0.03487500175833702
# , x: 0.7620037794113159
# y: 0.6616967916488647
# z: -0.05190255865454674
# , x: 0.7272680401802063
# y: 0.6285677552223206
# z: -0.07139725238084793
# , x: 0.6969720125198364
# y: 0.6141198873519897
# z: -0.09439156204462051
# , x: 0.7632384896278381
# y: 0.5520163178443909
# z: -0.009503714740276337
# , x: 0.7388123273849487
# y: 0.4945221543312073
# z: -0.019551323726773262
# , x: 0.7271048426628113
# y: 0.45562827587127686
# z: -0.031669750809669495
# , x: 0.7188080549240112
# y: 0.42129555344581604
# z: -0.04117005318403244
# , x: 0.7873939871788025
# y: 0.530464768409729
# z: -0.006880384869873524
# , x: 0.7654231786727905
# y: 0.4619182050228119
# z: -0.009874741546809673
# , x: 0.7542437314987183
# y: 0.42030811309814453
# z: -0.025330472737550735
# , x: 0.7455238699913025
# y: 0.38197779655456543
# z: -0.03602427616715431
# , x: 0.8152729868888855
# y: 0.5257877707481384
# z: -0.00954632367938757
# , x: 0.8001527786254883
# y: 0.46085238456726074
# z: -0.018544353544712067
# , x: 0.7927680611610413
# y: 0.420507550239563
# z: -0.036697614938020706
# , x: 0.7874578237533569
# y: 0.38298386335372925
# z: -0.05143580213189125
# , x: 0.8488302230834961
# y: 0.5346018671989441
# z: -0.0161301176995039
# , x: 0.8538756370544434
# y: 0.4848186671733856
# z: -0.031232204288244247
# , x: 0.8591665029525757
# y: 0.45319151878356934
# z: -0.048553578555583954
# , x: 0.8632431030273438
# y: 0.42127054929733276
# z: -0.06208588927984238
# ]

# %%
results.right_hand_landmarks.landmark[0]
# Out:
# x: 0.16967542469501495
# y: 0.5811815857887268
# z: -4.9005535402102396e-05

# %%
results.pose_landmarks.IsInitialized()
# Out:
# True

# %%
num_coords_two_hand =len(results.pose_landmarks.landmark)+21+21

# %%
num_coords_two_hand
# Out:
# 75

# %%
landmarks_of_two_hand = ['class']
for val in range(1, num_coords_two_hand+1):
    landmarks_of_two_hand += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
with open('two_hands_coordinates.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks_of_two_hand)

# %% [markdown]
# # Capture Landmarks & Export to CSV

# %%
#initialize class name
class_name = "ahln"

# %%
sec=(time.localtime().tm_sec+45)%60
sec2 = time.localtime().tm_sec     
print('called')
time.sleep(5)
print('called after break 5s')
cap = cv2.VideoCapture(2)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened() and sec2%60!=sec:
        sec2 = time.localtime().tm_sec
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            if isInitialized(results.pose_landmarks) == False:
                print("move back to appear")
            # Extract left_hand landmarks
            if isInitialized(results.left_hand_landmarks) == False:
                print("move back one step to detect left hand")
                    
            #Exract right_hand landmarks
            if isInitialized(results.right_hand_landmarks) == False:
                print("move back one step to detect right hand")

                    
            # Concate rows
            if isInitialized(results.pose_landmarks) == True and isInitialized(results.right_hand_landmarks) == True and isInitialized(results.left_hand_landmarks) == True:
                print("capturing")
                
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
           
                #left hand coordinates
                left_hand = results.left_hand_landmarks.landmark
                left_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in left_hand]).flatten())

                #right hand coordinates
                right_hand = results.right_hand_landmarks.landmark
                right_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in right_hand]).flatten())
                
                rowRLH = pose_row+right_hand_row+left_hand_row
                 # Append class name 
                rowRLH.insert(0, class_name)
                with open('two_hands_coordinates.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(rowRLH)
               

        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('p'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# called
# called after break 5s
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# capturing
# capturing
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# move back one step to detect left hand
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing
# capturing

# %% [markdown]
# # Train Custom Model Using Scikit Learn

# %% [markdown]
# #  Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('two_hands_coordinates.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1   v1        x2        y2        z2  \
# 0  wahed  0.526415  0.247950 -0.380534  1.0  0.540103  0.215349 -0.371085
# 1  wahed  0.530556  0.248421 -0.511866  1.0  0.543867  0.215677 -0.502954
# 2  wahed  0.530169  0.252634 -0.448285  1.0  0.543206  0.223845 -0.434164
# 3  wahed  0.527116  0.263875 -0.403779  1.0  0.538045  0.227855 -0.393453
# 4  wahed  0.523463  0.256325 -0.425642  1.0  0.535743  0.221671 -0.417403
#
#     v2        x3  ...       z73  v73       x74       y74       z74  v74  \
# 0  1.0  0.548962  ...  0.043284  0.0  0.654252  0.970526  0.046998  0.0
# 1  1.0  0.552590  ...  0.046989  0.0  0.659658  0.959095  0.050025  0.0
# 2  1.0  0.551402  ...  0.047993  0.0  0.665497  0.954012  0.052103  0.0
# 3  1.0  0.547238  ...  0.031853  0.0  0.658879  0.953308  0.034090  0.0
# 4  1.0  0.544832  ...  0.030367  0.0  0.658107  0.954570  0.031897  0.0
#
#         x75       y75       z75  v75
# 0  0.651312  0.974529  0.051050  0.0
# 1  0.654578  0.964612  0.052457  0.0
# 2  0.660693  0.961610  0.055459  0.0
# 3  0.655713  0.961063  0.035454  0.0
# 4  0.654948  0.962911  0.032447  0.0
#
# [5 rows x 301 columns]

# %%
df.tail()
# Out:
#       class        x1        y1        z1   v1        x2        y2        z2  \
# 12785  ahln  0.708610  0.157076 -0.262450  1.0  0.720657  0.131738 -0.237018
# 12786  ahln  0.707098  0.154699 -0.252282  1.0  0.718121  0.128726 -0.226630
# 12787  ahln  0.703254  0.150014 -0.253266  1.0  0.714264  0.123522 -0.227505
# 12788  ahln  0.703340  0.147285 -0.245611  1.0  0.714175  0.121122 -0.219716
# 12789  ahln  0.706087  0.144010 -0.260050  1.0  0.718051  0.117144 -0.230351
#
#         v2        x3  ...       z73  v73       x74       y74       z74  v74  \
# 12785  1.0  0.729222  ...  0.018945  0.0  0.830483  0.922768  0.016230  0.0
# 12786  1.0  0.726620  ...  0.023017  0.0  0.828192  0.909621  0.019308  0.0
# 12787  1.0  0.722863  ...  0.008189  0.0  0.840815  0.923896  0.002577  0.0
# 12788  1.0  0.722814  ...  0.004388  0.0  0.852666  0.927071  0.000644  0.0
# 12789  1.0  0.726899  ...  0.004442  0.0  0.858197  0.927998 -0.000261  0.0
#
#             x75       y75       z75  v75
# 12785  0.826094  0.930049  0.015379  0.0
# 12786  0.822408  0.909682  0.017346  0.0
# 12787  0.835181  0.931007 -0.000311  0.0
# 12788  0.848483  0.937715 -0.001555  0.0
# 12789  0.854342  0.937806 -0.003336  0.0
# 7540   0.0  0.713628  0.863412  0.048694  0.0
# 11468  0.0  0.573428  0.943496  0.012805  0.0
# 7221   0.0  0.752296  0.856919  0.053319  0.0
# 1318   0.0  0.582422  0.942625  0.007764  0.0
# 8915   0.0  0.499602  0.920556  0.006101  0.0
# 11055  0.0  0.582572  0.942572  0.025614  0.0
#
# [8953 rows x 300 columns]

# %% [markdown]
# # Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['5msa', '5msa', '34ra', ..., 'tmnya', 'sta', 'sb3a'], dtype=object)

# %% [markdown]
# # Evaluate and Serialize Model

# %% [markdown]
# # fitting model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9882720875684128
# rc 0.980453479280688
# rf 0.9874902267396404
# gb 0.9864477456346104

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['5msa', '5msa', '34ra', ..., 'tmnya', 'sta', 'sb3a'], dtype=object)

# %%
y_test
# Out:
# 1965      5msa
# 1852      5msa
# 7907      34ra
# 3950      34ra
# 1339     arb3a
# 4530     etnyn
# 4241     wahed
# 10531      sta
# 2444      sb3a
# 9825      5msa
# 5642     arb3a
# 11739     ts3a
# 11231    tmnya
# 12471     ahln
# 7192     tmnya
# 6103       sta
# 10583      sta
# 6708      sb3a
# 1413     arb3a
# 9944      5msa
# 11832     34ra
# 9206     tlata
# 12250     ahln
# 260      wahed
# 10485      sta
# 10213      sta
# 1701      5msa
# 10829     sb3a
# 6898      sb3a
# 10510      sta
#          ...
# 3417      ts3a
# 536      etnyn
# 1324     arb3a
# 6046      5msa
# 12116     34ra
# 10875     sb3a
# 7897      34ra
# 10639      sta
# 12052     34ra
# 7768      ts3a
# 8564     wahed
# 9759     arb3a
# 2533      sb3a
# 7449      ts3a
# 11648     ts3a
# 4359     wahed
# 1635     arb3a
# 7735      ts3a
# 35       wahed
# 2681      sb3a
# 10039     5msa
# 6006      5msa
# 1416     arb3a
# 3072     tmnya
# 5266     arb3a
# 247      wahed
# 12353     ahln
# 3001     tmnya
# 10232      sta
# 6933      sb3a
# Name: class, Length: 3837, dtype: object

# %%
#save trained model
with open('signs5.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # Make Detections with Model

# %%
with open('signs5.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            if isInitialized(results.pose_landmarks) == False:
                print("move back to appear")
           
            # Extract left_hand landmarks
            if isInitialized(results.left_hand_landmarks) == False:
                print("move back one step to detect left hand")
                    
            #Exract right_hand landmarks
            if isInitialized(results.right_hand_landmarks) == False:
                print("move back one step to detect right hand")

                    
            # Concate rows
            if isInitialized(results.pose_landmarks) == True and isInitialized(results.right_hand_landmarks) == True and isInitialized(results.left_hand_landmarks) == True:
                print("capturing")
                # Extract Pose landmarks
                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
                #left hand coordinates
                left_hand = results.left_hand_landmarks.landmark
                left_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in left_hand]).flatten())

                #right hand coordinates
                right_hand = results.right_hand_landmarks.landmark
                right_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in right_hand]).flatten())
                
                rowRLH = pose_row+right_hand_row+left_hand_row
                print(rowRLH)
                 # Make Detections
                X = pd.DataFrame([rowRLH])
                body_language_class = model.predict(X)[0]
                body_language_prob = model.predict_proba(X)[0]
                print(body_language_class, body_language_prob) 
                 # Grab ear coords
                coords = tuple(np.multiply(
                                np.array(
                                    (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                     results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                            , [640,480]).astype(int))

                cv2.rectangle(image, 
                              (coords[0], coords[1]+5), 
                              (coords[0]+len(body_language_class)*20, coords[1]-30), 
                              (245, 117, 16), -1)
                cv2.putText(image, body_language_class, coords, 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

                #
250521659851074, 0.0, 0.21888518333435059, 0.605938196182251, 0.1019240990281105, 0.0, 0.21589839458465576, 0.5982412695884705, 0.03035593405365944, 0.0, 0.21838857233524323, 0.5284711122512817, 0.0652366578578949, 0.0, 0.2209763526916504, 0.4886295199394226, 0.08782868087291718, 0.0, 0.22529515624046326, 0.46000736951828003, 0.09398341178894043, 0.0, 0.25532984733581543, 0.6032062768936157, 0.019112074747681618, 0.0, 0.2716885209083557, 0.5924286246299744, 0.07269717007875443, 0.0, 0.2646455466747284, 0.6205323934555054, 0.08718429505825043, 0.0, 0.25706490874290466, 0.6389541625976562, 0.08242227137088776, 0.0, 0.2908942401409149, 0.6236329078674316, 0.017091557383537292, 0.0, 0.30273619294166565, 0.6274012327194214, 0.07386936247348785, 0.0, 0.29290667176246643, 0.6521420478820801, 0.07693888247013092, 0.0, 0.2855689525604248, 0.6663013696670532, 0.060209374874830246, 0.0, 0.32402247190475464, 0.6506253480911255, 0.019328048452734947, 0.0, 0.33313629031181335, 0.6581318974494934, 0.06083015725016594, 0.0, 0.322578102350235, 0.679699361 ...
# tmnya [0.   0.21 0.   0.04 0.02 0.01 0.24 0.05 0.25 0.06 0.12]
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# ...
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b9ca7990e127> in <module>
# ----> 1 tensorflow.__version__
#
# NameError: name 'tensorflow' is not defined

# %%
def predict():
    
    mp_drawing = mp.solutions.drawing_utils
    mp_holistic = mp.solutions.holistic
    cap = cv2.VideoCapture(0)
    # Initiate holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        
        while cap.isOpened():
            ret, frame = cap.read()
            
            # Recolor Feed
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False        
            
            # Make Detections
            results = holistic.process(image)
            # print(results.face_landmarks)
            
            # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
            
            # Recolor image back to BGR for rendering
            image.flags.writeable = True   
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            
            # 1. Draw face landmarks
            mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                    mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                    mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                    )
            
            # 2. Right hand
            mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                    mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                    mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                    )

            # 3. Left Hand
            mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                    mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                    mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                    )

            # 4. Pose Detections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                    mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                    mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                    )
            # Export coordinates
            try:
                if isInitialized(results.pose_landmarks) == False:
                    print("move back to appear")
            
                # Extract left_hand landmarks
                if isInitialized(results.left_hand_landmarks) == False:
                    print("move back one step to detect left hand")
                        
                #Exract right_hand landmarks
                if isInitialized(results.right_hand_landmarks) == False:
                    print("move back one step to detect right hand")

                        
                # Concate rows
                if isInitialized(results.pose_landmarks) == True and isInitialized(results.right_hand_landmarks) == True and isInitialized(results.left_hand_landmarks) == True:
                    print("capturing")
                    # Extract Pose landmarks
                    pose = results.pose_landmarks.landmark
                    pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                
                    #left hand coordinates
                    left_hand = results.left_hand_landmarks.landmark
                    left_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in left_hand]).flatten())

                    #right hand coordinates
                    right_hand = results.right_hand_landmarks.landmark
                    right_hand_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in right_hand]).flatten())
                    
                    rowRLH = pose_row+right_hand_row+left_hand_row
                    # Make Detections
                    X = pd.DataFrame([rowRLH])
                    body_language_class = model.predict(X)[0]
                    body_language_prob = model.predict_proba(X)[0]
                    print(body_language_class, body_language_prob) 
                    # Grab ear coords
                    coords = tuple(np.multiply(
                                    np.array(
                                        (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                        results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                                , [640,480]).astype(int))

                    cv2.rectangle(image, 
                                (coords[0], coords[1]+5), 
                                (coords[0]+len(body_language_class)*20, coords[1]-30), 
                                (245, 117, 16), -1)
                    cv2.putText(image, body_language_class, coords, 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

                    # Get status box
                    cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)

                    # Display Class
                    cv2.putText(image, 'CLASS'
                                , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
                    cv2.putText(image, body_language_class.split(' ')[0]
                                , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

                    # Display Probability
                    cv2.putText(image, 'PROB'
                                , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
                    cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                                , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                    
                

            except:
                pass
                            
            cv2.imshow('Raw Webcam Feed', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

    cap.release()
    cv2.destroyAllWindows()
    return True

# %%
predict()
# Out:
# move back to appear
# move back one step to detect left hand
# move back one step to detect right hand
# move back to appear
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# capturing
# 5msa [0.   0.35 0.   0.03 0.   0.   0.32 0.01 0.16 0.09 0.04]
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect right hand
# capturing
# 5msa [0.   0.36 0.   0.03 0.05 0.04 0.09 0.03 0.19 0.14 0.07]
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect right hand
# capturing
# 5msa [0.01 0.23 0.   0.11 0.04 0.04 0.22 0.04 0.17 0.11 0.03]
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# capturing
# 5msa [0.   0.44 0.   0.07 0.03 0.   0.15 0.02 0.18 0.08 0.03]
# capturing
# 5msa [0.   0.4  0.   0.05 0.04 0.   0.17 0.03 0.25 0.04 0.02]
# capturing
# tmnya [0.   0.22 0.   0.02 0.07 0.07 0.12 0.04 0.34 0.09 0.03]
# capturing
# sb3a [0.   0.11 0.02 0.15 0.07 0.16 0.1  0.09 0.16 0.1  0.04]
# capturing
# wahed [0.09 0.09 0.01 0.14 0.11 0.09 0.08 0.03 0.07 0.13 0.16]
# move back one step to detect right hand
# move back one step to detect right hand
# capturing
# wahed [0.06 0.06 0.01 0.09 0.17 0.15 0.05 0.09 0.05 0.08 0.19]
# capturing
# sb3a [0.   0.09 0.01 0.16 0.07 0.26 0.08 0.12 0.06 0.1  0.05]
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# capturing
# tmnya [0.   0.24 0.   0.04 0.05 0.07 0.12 0.05 0.3  0.11 0.02]
# capturing
# sb3a [0.02 0.07 0.02 0.13 0.11 0.22 0.08 0.12 0.06 0.09 0.08]
# capturing
# sb3a [0.   0.06 0.01 0.13 0.16 0.18 0.06 0.15 0.08 0.08 0.09]
# capturing
# sb3a [0.01 0.05 0.03 0.13 0.15 0.17 0.07 0.15 0.06 0.1  0.08]
# capturing
# sb3a [0.   0.09 0.   0.08 0.08 0.23 0.18 0.07 0.11 0.14 0.02]
# capturing
# sb3a [0.   0.12 0.   0.09 0.07 0.23 0.11 0.07 0.16 0.13 0.02]
# capturing
# sb3a [0.   0.14 0.   0.12 0.06 0.22 0.1  0.07 0.17 0.1  0.02]
# capturing
# sb3a [0.   0.14 0.   0.1  0.07 0.22 0.1  0.07 0.16 0.12 0.02]
# capturing
# sb3a [0.   0.12 0.   0.09 0.07 0.23 0.11 0.07 0.16 0.13 0.02]
# capturing
# sb3a [0.   0.12 0.   0.12 0.09 0.24 0.11 0.09 0.14 0.07 0.02]
# capturing
# tmnya [0.08 0.1  0.   0.15 0.12 0.08 0.08 0.08 0.17 0.07 0.07]
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect right hand
# capturing
# tmnya [0.04 0.13 0.   0.17 0.15 0.09 0.06 0.06 0.21 0.06 0.03]
# capturing
# tmnya [0.07 0.13 0.   0.13 0.16 0.06 0.08 0.04 0.24 0.04 0.05]
# capturing
# tmnya [0.09 0.13 0.   0.1  0.17 0.05 0.13 0.05 0.21 0.02 0.05]
# capturing
# tmnya [0.1  0.15 0.   0.09 0.16 0.05 0.14 0.05 0.2  0.01 0.05]
# capturing
# tmnya [0.13 0.12 0.   0.11 0.1  0.05 0.13 0.06 0.22 0.01 0.07]
# capturing
# tmnya [0.11 0.14 0.   0.09 0.13 0.06 0.12 0.06 0.22 0.02 0.05]
# capturing
# tmnya [0.12 0.13 0.   0.11 0.16 0.05 0.12 0.05 0.22 0.01 0.03]
# capturing
# etnyn [0.03 0.08 0.   0.17 0.2  0.08 0.07 0.11 0.19 0.05 0.02]
# capturing
# tmnya [0.   0.24 0.   0.05 0.04 0.01 0.24 0.05 0.27 0.07 0.03]
# capturing
# tmnya [0.   0.14 0.   0.02 0.06 0.05 0.23 0.03 0.32 0.14 0.01]
# capturing
# tmnya [0.   0.23 0.01 0.02 0.05 0.06 0.14 0.02 0.35 0.11 0.01]
# capturing
# tmnya [0.06 0.09 0.   0.18 0.18 0.06 0.05 0.07 0.24 0.03 0.04]
# capturing
# tmnya [0.09 0.13 0.   0.13 0.17 0.06 0.08 0.04 0.23 0.02 0.05]
# capturing
# tmnya [0.1  0.14 0.   0.13 0.15 0.08 0.08 0.03 0.23 0.03 0.03]
# capturing
# tmnya [0.1  0.12 0.   0.15 0.15 0.06 0.09 0.04 0.21 0.05 0.03]
# capturing
# tmnya [0.11 0.13 0.   0.13 0.13 0.06 0.08 0.05 0.24 0.01 0.06]
# capturing
# tmnya [0.08 0.11 0.   0.11 0.12 0.02 0.14 0.05 0.26 0.05 0.06]
# capturing
# tmnya [0.06 0.13 0.   0.1  0.13 0.02 0.16 0.04 0.25 0.04 0.07]
# capturing
# tmnya [0.03 0.13 0.   0.1  0.12 0.01 0.16 0.05 0.32 0.05 0.03]
# capturing
# tmnya [0.   0.25 0.   0.07 0.05 0.01 0.2  0.05 0.31 0.03 0.03]
# capturing
# tmnya [0.01 0.2  0.   0.09 0.06 0.01 0.17 0.03 0.31 0.08 0.04]
# capturing
# tmnya [0.01 0.21 0.   0.07 0.06 0.02 0.22 0.03 0.28 0.08 0.02]
# capturing
# tmnya [0.04 0.12 0.   0.21 0.13 0.06 0.13 0.06 0.22 0.02 0.01]
# capturing
# tmnya [0.02 0.18 0.   0.11 0.09 0.03 0.17 0.03 0.28 0.07 0.02]
# capturing
# tmnya [0.   0.26 0.   0.05 0.04 0.   0.25 0.03 0.29 0.05 0.03]
# capturing
# 5msa [0.   0.3  0.   0.04 0.03 0.   0.24 0.03 0.28 0.02 0.06]
# capturing
# tmnya [0.02 0.19 0.   0.05 0.02 0.   0.28 0.03 0.33 0.03 0.05]
# move back one step to detect right hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# move back one step to detect left hand
# move back one step to detect right hand
# True

# %%
cv2.__version__
# Out:
# '4.5.1'

# %%
import sklearn as sk
sk.__version__
# Out:
# '0.24.1'

# %%
import pickle 
print(pickle.format_version)
# Out:
# 4.0

# %%
np.__version__
# Out:
# '1.18.3'

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
csv.__version__
# Out:
# '1.0'

# %%
from csv import
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-93d9f20194b9> in <module>
# ----> 1 mp.__version__
#
# AttributeError: module 'mediapipe' has no attribute '__version__'
